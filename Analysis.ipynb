# %%
#Phase-1

#Loading the Dataset
import pandas as pd
df = pd.read_csv("Project_1Data.csv")
# print(df)
df.head()
df.tail()
print("Shape : ",df.shape)
print(f"The Columns in this dataset are  {list(df.columns)}")

df.isnull()#Checking the Null values /Bad practice 

print(f"Total Null values in this datasest Per Column : \n{df.isnull().sum()}")#Good practice
df.duplicated()#Checking the Duplicates /Bad practice

print(f"Total duplicates rows in this data set are : {df.duplicated().sum()}")# Good practice to find duplicates Number


#Phase-2

#cleaning the data 
df['OrderDate'] = pd.to_datetime(df['OrderDate'])

df['OrderDate'] #fixing the Dates by changing its data type object to DateTime 

#Changing the datatype of Numeric columns
df['Quantity'] = df['Quantity'].astype(int)
df['Price']=df['Price'].astype(float)
df['Revenue']=df['Revenue'].astype(float)

#Revenue Sanity check 

#Formula : Revenue = Quantity * Price 

df['CalculatedRevenue'] = df['Quantity']*df['Price']
df['CalculatedRevenue']
(df['Revenue'] == df['CalculatedRevenue']).value_counts()


df['Revenue'] = df['CalculatedRevenue']
df.drop(columns =['CalculatedRevenue'],inplace = True)
# df[1:2]


#Phase-3

#EDA & Getting buisness Insights 

#Total Order
print(f"Total Order : {df['Quantity'].sum()}")

#Revenue 
print(f"Total Revenue Generated from the Orders : {df['Revenue'].sum()}")



#Month Wise total Revenue 

#first Getting the Months 
df['Month'] =df['OrderDate'].dt.month
df[:]

#Montly Revenue
print(f"Total Revenue Genertaed per Month : \n{df.groupby('Month')['Revenue'].sum()}")



#BEst REvenue Month
# Out:
# Shape :  (500, 8)
# The Columns in this dataset are  ['OrderID', 'OrderDate', 'Product', 'Category', 'City', 'Quantity', 'Price', 'Revenue']
# Total Null values in this datasest Per Column :
# OrderID      0
# OrderDate    0
# Product      0
# Category     0
# City         0
# Quantity     0
# Price        0
# Revenue      0
# dtype: int64
# Total duplicates rows in this data set are : 0
# Total Order : 1531
# Total Revenue Generated from the Orders : 2374469.0
# Total Revenue Genertaed per Month :
# Month
# 1     321356.0
# 2     194926.0
# 3     186961.0
# 4     221492.0
# 5     165616.0
# 6     195613.0
# 7     108477.0
# 8     221578.0
# 9     120730.0
# 10    229924.0
# 11    269617.0
# 12    138179.0
# Name: Revenue, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 68
# ...
